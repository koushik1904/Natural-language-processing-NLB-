# %% [markdown]
# <a href="https://colab.research.google.com/github/koushik1904/Natural-language-processing-NLB-/blob/main/NLPLAB2_2403A52057.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import nltk
import spacy

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
# Download NLTK resources
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Medical text corpus
medical_text = """
The patient was diagnosed with diabetes mellitus.
Prescribed medications include insulin injections.
Doctors are monitoring blood glucose levels regularly.
Early diagnosis helps in preventing complications.
"""

# %%
import nltk

# Download required NLTK tokenizers
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Sentence tokenization using NLTK
sentences = sent_tokenize(medical_text)

print("Sentences:")
for s in sentences:
    print("-", s)
# Out:
# Sentences:
# -
# The patient was diagnosed with diabetes mellitus.
# - Prescribed medications include insulin injections.
# - Doctors are monitoring blood glucose levels regularly.
# - Early diagnosis helps in preventing complications.

# %%
from nltk.tokenize import sent_tokenize

sentences = sent_tokenize(medical_text)

print("Sentences:")
for s in sentences:
    print("-", s)
# Out:
# Sentences:
# -
# The patient was diagnosed with diabetes mellitus.
# - Prescribed medications include insulin injections.
# - Doctors are monitoring blood glucose levels regularly.
# - Early diagnosis helps in preventing complications.

# %%
# Import word tokenizer
from nltk.tokenize import word_tokenize

# Perform word tokenization
words = word_tokenize(medical_text)

# Display words
print("Words:")
print(words)
# Out:
# Words:
# ['The', 'patient', 'was', 'diagnosed', 'with', 'diabetes', 'mellitus', '.', 'Prescribed', 'medications', 'include', 'insulin', 'injections', '.', 'Doctors', 'are', 'monitoring', 'blood', 'glucose', 'levels', 'regularly', '.', 'Early', 'diagnosis', 'helps', 'in', 'preventing', 'complications', '.']

# %%
# Load spaCy English model
import spacy
nlp = spacy.load("en_core_web_sm")

# Process medical text
doc = nlp(medical_text)

# Display spaCy tokens
print("spaCy Tokens:")
for token in doc:
    print(token.text)
# Out:
# spaCy Tokens:
#
#
# The
# patient
# was
# diagnosed
# with
# diabetes
# mellitus
# .
#
#
# Prescribed
# medications
# include
# insulin
# injections
# .
#
#
# Doctors
# are
# monitoring
# blood
# glucose
# levels
# regularly
# .
#
#
# Early
# diagnosis
# helps
# in
# preventing
# complications
# .

# %%
# Import stemmer
from nltk.stem import PorterStemmer

# Initialize stemmer
stemmer = PorterStemmer()

# Apply stemming
stemmed_words = [stemmer.stem(word) for word in words]

# Display stemmed words
print("Stemmed Words:")
print(stemmed_words)
# Out:
# Stemmed Words:
# ['the', 'patient', 'wa', 'diagnos', 'with', 'diabet', 'mellitu', '.', 'prescrib', 'medic', 'includ', 'insulin', 'inject', '.', 'doctor', 'are', 'monitor', 'blood', 'glucos', 'level', 'regularli', '.', 'earli', 'diagnosi', 'help', 'in', 'prevent', 'complic', '.']

# %%
# Import lemmatizer
from nltk.stem import WordNetLemmatizer

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Apply lemmatization
lemmatized_words = [lemmatizer.lemmatize(word) for word in words]

# Display lemmatized words
print("Lemmatized Words:")
print(lemmatized_words)
# Out:
# Lemmatized Words:
# ['The', 'patient', 'wa', 'diagnosed', 'with', 'diabetes', 'mellitus', '.', 'Prescribed', 'medication', 'include', 'insulin', 'injection', '.', 'Doctors', 'are', 'monitoring', 'blood', 'glucose', 'level', 'regularly', '.', 'Early', 'diagnosis', 'help', 'in', 'preventing', 'complication', '.']

# %%
# Display spaCy lemmatization
print("spaCy Lemmatization:")
for token in doc:
    print(f"{token.text} → {token.lemma_}")
# Out:
# spaCy Lemmatization:
#
#  →
#
# The → the
# patient → patient
# was → be
# diagnosed → diagnose
# with → with
# diabetes → diabete
# mellitus → mellitus
# . → .
#
#  →
#
# Prescribed → prescribed
# medications → medication
# include → include
# insulin → insulin
# injections → injection
# . → .
#
#  →
#
# Doctors → doctor
# are → be
# monitoring → monitor
# blood → blood
# glucose → glucose
# levels → level
# regularly → regularly
# . → .
#
#  →
#
# Early → early
# diagnosis → diagnosis
# helps → help
# in → in
# preventing → prevent
# complications → complication
# . → .
#
#  →

# %%
# Compare stemming and lemmatization side by side

print(f"{'Word':<15}{'Stemmed':<15}{'Lemmatized':<15}")
print("-" * 45)

for word in words:
    stem = stemmer.stem(word)
    lemma = lemmatizer.lemmatize(word)
    print(f"{word:<15}{stem:<15}{lemma:<15}")
# Out:
# Word           Stemmed        Lemmatized
# ---------------------------------------------
# The            the            The
# patient        patient        patient
# was            wa             wa
# diagnosed      diagnos        diagnosed
# with           with           with
# diabetes       diabet         diabetes
# mellitus       mellitu        mellitus
# .              .              .
# Prescribed     prescrib       Prescribed
# medications    medic          medication
# include        includ         include
# insulin        insulin        insulin
# injections     inject         injection
# .              .              .
# Doctors        doctor         Doctors
# are            are            are
# monitoring     monitor        monitoring
# blood          blood          blood
# glucose        glucos         glucose
# levels         level          level
# regularly      regularli      regularly
# .              .              .
# Early          earli          Early
# ...
